# %%
import pandas as pd

# %%
# read data
df=pd.read_csv('Data/survey_results_public.csv')

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
#Remove unnecessary columns
df1=df.drop(columns=['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
        'CompTotal', 'CurrencyDesc',
       'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
      'EdLevel', 'Employment', 'Ethnicity',  'JobFactors',
       'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
       'MiscTechDesireNextYear', 'MiscTechWorkedWith',
       'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
       'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
       'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
       'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
       'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
       'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
       'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
       'Trans', 'UndergradMajor', 'WebframeDesireNextYear',
       'WebframeWorkedWith', 'WelcomeChange', 'WorkWeekHrs', 'YearsCode',
       'YearsCodePro'])
df1
# Out:
#        Respondent  ConvertedComp             Country  \
# 0               1            NaN             Germany
# 1               2            NaN      United Kingdom
# 2               3            NaN  Russian Federation
# 3               4            NaN             Albania
# 4               5            NaN       United States
# ...           ...            ...                 ...
# 64456       64858            NaN       United States
# 64457       64867            NaN             Morocco
# 64458       64898            NaN            Viet Nam
# 64459       64925            NaN              Poland
# 64460       65112            NaN               Spain
#
#                                                  DevType Gender
# 0      Developer, desktop or enterprise applications;...    Man
# 1                Developer, full-stack;Developer, mobile    NaN
# 2                                                    NaN    NaN
# 3                                                    NaN    Man
# ...

# %%
#sort
df1.sort_values(by='Country',ascending=True)
df1.sort_values(by=['Country','ConvertedComp'],ascending=[True,False]) #each country with max comptotal
# Out:
#        Respondent  ConvertedComp      Country  \
# 61540       62788      1000000.0  Afghanistan
# 63925       65381      1000000.0  Afghanistan
# 63993       65456      1000000.0  Afghanistan
# 38261       38672       231192.0  Afghanistan
# 28270       28374       130000.0  Afghanistan
# ...           ...            ...          ...
# 64425       60055            NaN          NaN
# 64431       61121            NaN          NaN
# 64434       61570            NaN          NaN
# 64436       61918            NaN          NaN
# 64440       62605            NaN          NaN
#
#                                                  DevType Gender
# 61540                                          Scientist    NaN
# 63925  Data or business analyst;Data scientist or mac...    NaN
# 63993                                                NaN    NaN
# 38261                                                NaN    NaN
# 28270  Developer, desktop or enterprise applications;...    Man
# ...

# %%
#first 5 largest Values of convertedcomp
df1.nlargest(5,'ConvertedComp')
# Out:
#      Respondent  ConvertedComp        Country  \
# 121         123      2000000.0  United States
# 123         125      2000000.0  United States
# 191         193      2000000.0  United States
# 663         665      2000000.0  United States
# 697         699      2000000.0  United States
#
#                                                DevType Gender
# 121          Developer, back-end;Developer, full-stack    Man
# 123  Data scientist or machine learning specialist;...    Man
# 191                                  Developer, mobile    Man
# 663                               Developer, front-end  Woman
# 697                               System administrator    Man

# %%
#mean calc
df['ConvertedComp'].mean()
# Out:
# 103756.05014961446

# %%
#median calc
df1['ConvertedComp'].median()
# Out:
# 54049.0

# %%
#5 numbers summary of data
df1.describe()
# Out:
#          Respondent  ConvertedComp
# count  64461.000000   3.475600e+04
# mean   32554.079738   1.037561e+05
# std    18967.442360   2.268853e+05
# min        1.000000   0.000000e+00
# 25%    16116.000000   2.464800e+04
# 50%    32231.000000   5.404900e+04
# 75%    49142.000000   9.500000e+04
# max    65639.000000   2.000000e+06

# %%
#ValueCounts
df1['Country'].value_counts()
df1['Country'].value_counts(normalize=True)
# Out:
# United States       0.194609
# India               0.131149
# United Kingdom      0.060807
# Germany             0.060713
# Canada              0.034196
#                       ...
# Kiribati            0.000016
# Nauru               0.000016
# Lesotho             0.000016
# Saint Lucia         0.000016
# Marshall Islands    0.000016
# Name: Country, Length: 183, dtype: float64
